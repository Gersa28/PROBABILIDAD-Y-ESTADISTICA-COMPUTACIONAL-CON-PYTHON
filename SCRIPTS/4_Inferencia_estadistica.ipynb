# %% [markdown]
# # INFERENCIA ESTADÍSTICA

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Sacaremos conclusiones a partir de una muestra ALEATORIA. Calcularemos los parámetros que la describen.

# %%
import random
import math

def media(X):
    return sum(X) / len(X)


def varianza(X):
    mu = media(X)

    acumulador = 0
    for x in X:
        acumulador += (x - mu)**2

    return acumulador / len(X)


def desviacion_estandar(X):
    return math.sqrt(varianza(X))


if __name__ == '__main__':
    X = [random.randint(9, 12) for i in range(20)]
    mu = media(X)
    Var = varianza(X)
    sigma = desviacion_estandar(X)

    print(f'Arreglo X: {X}')
    print(f'Media = {mu}')
    print(f'Varianza = {Var}')
    print(f'Desviacion estandar = {sigma}')
# Out:
# Arreglo X: [11, 12, 12, 9, 10, 12, 12, 10, 10, 11, 10, 10, 9, 10, 12, 9, 10, 10, 9, 11]
# Media = 10.45
# Varianza = 1.1475000000000002
# Desviacion estandar = 1.0712142642814275

# %%
import random
import statistics

if __name__ == '__main__':

    edades = X
    print("Arreglo X:", edades)
    print("Media = ",statistics.mean(edades))
    print("Varianza = ",statistics.variance(edades))
    print("Desvío estandar = ",statistics.stdev(edades))
    print("Covarianza = ",statistics.covariance(edades,edades))
# Out:
# Arreglo X: [11, 12, 12, 9, 10, 12, 12, 10, 10, 11, 10, 10, 9, 10, 12, 9, 10, 10, 9, 11]
# Media =  10.45
# Varianza =  1.2078947368421054
# Desvío estandar =  1.0990426455975697
# Covarianza =  1.2078947368421051

# %% [markdown]
# # Distribución Normal
# ![image.png](attachment:image.png)
